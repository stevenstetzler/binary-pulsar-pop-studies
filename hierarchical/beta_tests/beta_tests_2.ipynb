# %%
import beta_tests

# %%
alphas_1, betas_1 = beta_tests.run_simulation(1, 1, 31, niter=100000)
# Out:
# 99.9% Done
# Cannot corner plot
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-eaf5db65fea2> in <module>()
# ----> 1 alphas_1, betas_1 = beta_tests.run_simulation(1, 1, 31, niter=100000)
#
# TypeError: 'NoneType' object is not iterable

# %%
alphas_2, betas_2 = beta_tests.run_simulation(1, 1, 31, niter=100000)

# %%
alphas_1
